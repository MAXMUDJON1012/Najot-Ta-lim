# %%
# datatim time random string

# %%
import time 
import datetime


print("Hello World ")
time.sleep(5)
print("Men turdim")
today = datetime.datetime.today()
print(today)

# %%
# # # datetime, time, random, string
# import time
# import datetime

# print("Hammaga salom!")
# time.sleep(5)
# print("Men turdim!")

# today = datetime.datetime.today()
# print(today)






# from datetime import datetime, date, timedelta

# today = date.today()

# print(today.day, today.month, today.year)
# print(today)

# d1 = timedelta(days=7, seconds=12)
# d2 = timedelta(days=8)

# print(d2-d1)

# birth_day = date(year=2026, month=10, day=19)
# today = date.today()

# print(today - birth_day)


import random

minimal = 0
maksimal =100
count = 0
while True:
    try:
        taxmin = random.randint(minimal, maksimal)
        count += 1
        print(f"Siz o'ylagan son: {taxmin}")
        natija = input("To'g'rimi? (>, <, =): ")
        if natija == ">":
            minimal = taxmin + 1
        elif natija == "<":
            maksimal = taxmin - 1
        else:
            print(f"{count} ta urinishda topdim🎉")
            break
    except:
        print("Siz aldadingiz!")
        break
# Out:
# Siz o'ylagan son: 7
# Siz o'ylagan son: 9
# Siz o'ylagan son: 10
# Siz aldadingiz!

# %%
import calculator
print(calculator.kupaytirish(4,7))

# %%
def  son(a):
    if type(a)==int(a):
        return ("son")
    else:
        raise ValueError ("son kirgaz")
print(son(1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 6
#       2     if type(a)==int(a):
#       3         return ("son")
#       4     else:
#       5         raise ValueError ("son kirgaz")
# ----> 6 print(son(1))
#
# Cell In[6], line 5, in son(a)
#       1 def  son(a):
#       2     if type(a)==int(a):
#       3         return ("son")
#       4     else:
# ----> 5         raise ValueError ("son kirgaz")
#
# ValueError: son kirgaz
