# %%
def calculator (a, b):
    assert type (a) in (int, float), "Faqat butun sonlar kerak"
    assert type (b) in (int, float), "Faqat butun sonlar kerak"
    # if b == 0:
    #     raise   ZeroDivisionError("2- son 0 bo'lmasligi kerak !")
    # if (not type(a) in [int, float]) or (not type (b)) in [int, float]:
    return a/b
print(calculator(10.56,"8"))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 8
#       4     # if b == 0:
#       5     #     raise   ZeroDivisionError("2- son 0 bo'lmasligi kerak !")
#       6     # if (not type(a) in [int, float]) or (not type (b)) in [int, float]:
#       7     return a/b
# ----> 8 print(calculator(10.56,"8"))
#
# Cell In[2], line 3, in calculator(a, b)
#       1 def calculator (a, b):
#       2     assert type (a) in (int, float), "Faqat butun sonlar kerak"
# ----> 3     assert type (b) in (int, float), "Faqat butun sonlar kerak"
#       4     # if b == 0:
#       5     #     raise   ZeroDivisionError("2- son 0 bo'lmasligi kerak !")
#       6     # if (not type(a) in [int, float]) or (not type (b)) in [int, float]:
#
# AssertionError: Faqat butun sonlar kerak
