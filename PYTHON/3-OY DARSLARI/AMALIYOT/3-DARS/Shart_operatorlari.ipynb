# %%
a,b,c = map(int, input("enter number: ").split())

if a<=b<=c or a>=b>=c:
    pass
else:
    a *= -1
    b *= -1
    c *= -1

print(a, b, c)
# Out:
# -5 -6 -3

# %%
a,b = map(int, input("enter number: ").split())
for i  in range(a,b+1,2): 
    print(i)
# Out:
# 1
# 3
