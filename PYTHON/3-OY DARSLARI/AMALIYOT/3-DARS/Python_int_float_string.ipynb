# %%
Name=input("Enter the your name! ")
print(f"Hello {Name}")
# Out:
# Hello ali

# %%
n1=int(input("Enter number! "))
n2=int(input("Enter number! "))
print(n1+n2,n1*n2,n1/n2)
# Out:
# 8 12 3.0

# %%
age=int(input("Enter your age"))
if age > 18:
    print("voyagayrtgan")
else:
    print("Voyaga yetmagan")
# Out:
# Voyaga yetmagan

# %%
text=input("enter the text!")
len=0
for letter in text:
    len+=1
print(f"Text {len}ta xarifdan iborat")
# Out:
# Text 3ta xarifdan iborat

# %%
n1=float(input("Enter number! "))
n2=float(input("Enter number! "))
print((n1+n2)/2)
# Out:
# 3.9

# %%
text=input("enter the text!")
print(text[::-1])
# Out:
# ila

# %%
n1=int(input("Enter number! "))
if n1%5==0:
    print("bo'linadi")
else:
    print("bo'linmaydi")
# Out:
# bo'linadi

# %%
text=input("enter the text!")
print(text.split( ))
# Out:
# ['ali', 'valiev']

# %%
text=input("enter the text!")
print(text.upper())
print(text.lower())
# Out:
# ALI
# ali

# %%
n1=float(input("Enter number! "))
n2=float(input("Enter number! "))
n3=float(input("Enter number! "))
p=n1+n2+n3
print(p)
# Out:
# 3.5999999999999996

# %%
text=input("enter the text!")
sp=text.split()
count=0
print(sp)
for sprate in sp:
    count+=1
    print(count)
# Out:
# ['fdfd']
# 1

# %%
n1=int(input("Enter number! "))
n2=int(input("Enter number! "))
if n1>n2:
    print(n1)
elif n2>n1:
    print("n2")
else:
    print("ikkovi teng")
# Out:
# n2

# %%
text=input("enter the text!")
letter=input("Enter letter")
count=0
for i in text:
    if i==letter:
        count+=1
print(f"{letter} xarifi {count} marotaba takrolandi.")
# Out:
# a xarifi 2 marotaba takrolandi.

# %%
n1=int(input("Enter number! "))
QQS=(n1/100)*15
calculate=QQS+n1
print(calculate)
# Out:
# 28.75

# %%
text=input("enter the text!")
print(text[0])
print(text[-1])
# Out:
# a
# i

# %%
n1=input("Enter number! ")
calculate=0
for i in n1:
    calculate+=int(i)
print(calculate)
# Out:
# 6

# %%
text1=input("enter the text!")
text2=input("enter the text!")
print(text1+" "+text2)
# Out:
# salom ali

# %%
celsius = float(input("Celsius haroratni kiriting: "))
fahrenheit = celsius * 9 / 5 + 32
print(f"{celsius}°C harorat {fahrenheit}°F ga teng.")

# %%
text=input("enter the text!")
space=" "
count=0
for i in text:
    if i==space:
        count+=1
print(f"Space {count} marotaba takrolandi.")
# Out:
# Space 3 marotaba takrolandi.

# %%
a=float(input("enter value"))
b=float(input("enter value"))
s=a*b
if s>50:
    print("Big rectangle")
else:
    print("Smal rectangule")
# Out:
# Big rectangle
