# %%
number =int(input("son kiriting!"))
son=2
print(number)
print(type(number))
print("multilply: ",number*son)
print("devise",number/son)
print("add",number+son)
print("remove",number-son)
# Out:
# 5
# <class 'int'>
# multilply:  10
# devise 2.5

# %%
print("rest",number % son)
print("degree",number**2)
print("Root",number**1/son)
# Out:
# rest 1
# degree 25
# Root 2.5

# %%
number=int(input())
if number > 0:
  number+=1
print(number)
# Out:
# -7

# %%
simble=input("Enter the simble! ")
print(simble.isalpha())
# Out:
# False

# %%
simble=input("Enter the simble! ")
print(simble.isalnum())
# Out:
# True

# %%
simble=input("Enter the simble! ")
print("simble:",simble.isascii() and not simble.isalnum())
# Out:
# simble: True

# %%
matn="nd jbfj gch bckv JGDjvh cvzxn bn"
soni=0
for belgi in matn:
    soni +=belgi.isupper()
print(f"katta hariflar soni {soni} ta")
# Out:
# katta hariflar soni 3 ta

# %%
matn="nd jbfj gch bckv JGDjvh cvzxn 1 bn 5"
soni=0
for belgi in matn:
    soni +=belgi.isdigit()
print(f"Raaqamlar soni {soni} ta")
# Out:
# katta hariflar soni 2 ta

# %%
matn="bhvzhjvsd  bjdfjbrd bdjbgdjkbdk"
soni=0
for  belgi in matn:
    soni+=belgi.isdigit()
print(f"raqamlar soni {soni}")
# Out:
# raqamlar soni 0

# %%
matn = "nd jbfj gch bckv JGDjvh cvzxn 1 bn 5"
sonlar = []
for son in matn:
    if 48 <= ord(son) <= 57:
        sonlar.append(int(son))
print(sum(sonlar))
# Out:
# 6

# %%
matn = "nd jbfj gch bckv JGDjvh cvzxn 1 bn 5"
yangi_matn=""
for harf in matn:
    if 97<=ord(harf)<=122:
        yangi_matn+=harf.lower()
    elif 65<=ord(harf)<=90:
        yangi_matn+=harf.lower()
print(yangi_matn)
# Out:
# ndjbfjgchbckvjgdjvhcvzxnbn

# %%
a = [1, 2, 3, 4, 5]

a.reverse()

print(a)
# Out:
# [5, 4, 3, 2, 1]

# %%
matn = "salom"

print(matn[::-1])
# Out:
# molas

# %%
matn = "salom"
teskari = ""
for i in matn:
    teskari = i + teskari
print(teskari)
# Out:
# molas

# %%
matn="12"
summ=[]
for son in matn:
    summ.append(int(son))
print(sum(summ))
# Out:
# 3

# %%
matn = "salom"
x = "a"
yangi = ""

for harf in matn:
    if harf == x:
        yangi += harf * 2
    else:
        yangi += harf
print(yangi)
# Out:
# saalom

# %%
s1="abdadkmkns"
s2="tds"
count=0
for harf in s2:
    if harf in s1:
        count=count+1
print(count)
# Out:
# 2
