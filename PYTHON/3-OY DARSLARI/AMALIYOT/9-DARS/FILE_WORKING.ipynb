# %%
# file_name = "C:/Users/MAXMU/Desktop/Najot Talim/PYTHON/3-OY/AMALIYOT/9-DARS/sonlar.txt"     TUZATISH  KERAK ! 
with open ( file ="sonlar.txt" , mode = "r") as  f:
    sonlar = f.readline()
    print(type(sonlar))
    sonlar_int = list (map(int, sonlar.split(",")))
    print(sonlar_int)
    print(sum(sonlar_int))
# Out:
# <class 'str'>
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 45

# %%
savatcha = [
    {
        "nomi": "Noutbuk",
        "narxi": 8500000,
        "soni": 1
    },
    {
        "nomi": "Sichqoncha (Mouse)",
        "narxi": 150000,
        "soni": 2
    },
    {
        "nomi": "Klaviatura",
        "narxi": 350000,
        "soni": 1
    }
]



file_name="matn.txt"
with open (file_name,"a") as f :
    for m in savatcha :
        f.write(m["nomi"])
        f.write("|||")
        f.write(str(m["narxi"]))
        f.write("|||")
        f.write(str(m["soni"]))
        f.write("\n")
    print("saqlandi")
# Out:
# saqlandi

# %%
from pprint import pprint
savatcha = []
with open (file_name, "r") as f :
    for line in f.readlines():
        print(line)
        nomi,narxi,soni = line.split("|||")
        maxsulot={
            "nomi": nomi,
            "narxi": int(narxi),
            "soni": int(soni)
        }
print(savatcha)
# Out:
# Sichqoncha (Mouse)|||150000|||2
#
# Klaviatura|||350000|||1
#
# Noutbuk|||8500000|||1
#
# Sichqoncha (Mouse)|||150000|||2
#
# Klaviatura|||350000|||1
#
# Noutbuk|||8500000|||1
#
# Sichqoncha (Mouse)|||150000|||2
#
# Klaviatura|||350000|||1
#
# Noutbuk|||8500000|||1
#
# Sichqoncha (Mouse)|||150000|||2
#
# Klaviatura|||350000|||1
#
# []

# %%
file_name = "mevalar.txt"
fruits = []

for i in range(1, 4):
    fruit = input(f"{i}-meva nomini kiriting: ")
    fruits.append(fruit)
print(fruits)
with open(file_name, "w") as f:
    f.write(str(fruits))
print("Mevalar faylga muvaffaqiyatli yozildi!")
# Out:
# ['a', 's', 's']
# Mevalar faylga muvaffaqiyatli yozildi!
