# %%
import math
import random
import datetime
import os

# %%
try:
    son1 = float(input("Son kiriting: "))
    if son1 < 0:
        print("Manfiy sonning ildizi yo'q")
    else:
        print(math.sqrt(son1))
except ValueError ("xato"):
    print("Iltimos, son kiriting!")
# Out:
# 2.345207879911715

# %%
son2 = float(input("Son kiriting: "))
print("Ceil:", math.ceil(son2))
print("Floor:", math.floor(son2))
# Out:
# Ceil: 6
# Floor: 5

# %%
tasodifiy_sonlar = [random.randint(1, 100) for _ in range(5)]
print("Sonlar:", tasodifiy_sonlar, "Yig'indisi:", sum(tasodifiy_sonlar))
# Out:
# Sonlar: [41, 22, 41, 23, 50] Yig'indisi: 177

# %%
mevalar = ["olma", "banan", "uzum", "shaftoli", "gilos"]
print(random.choice(mevalar))
# Out:
# gilos

# %%
bugun = datetime.date.today()
print(bugun.strftime("%d-%m-%Y"))
# Out:
# 11-07-2026

# %%
tugilgan_yil = int(input("Tug'ilgan yilingizni kiriting: "))
joriy_yil = datetime.date.today().year
print(f"Siz {joriy_yil - tugilgan_yil} yoshdasiz.")
# Out:
# Siz 21 yoshdasiz.

# %%
print("Joriy papka:", os.getcwd())
print("Fayllar ro'yxati:", os.listdir())
# Out:
# Joriy papka: c:\Users\MAXMU\Desktop\Najot Talim\PYTHON\3-OY DARSLARI\HOMETASKS\8-DARS VAZIFASI
# Fayllar ro'yxati: ['chiqarish.ipynb', 'Modullar_bilan_Ishlash.ipynb', 'xisoblash.ipynb']

# %%
import xisoblash
print("Uchburchak yuzi:", xisoblash.uchburchak_yuza(10, 5))
print("To'rtburchak yuzi:", xisoblash.tortburchak_yuza(10, 5))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import xisoblash
#       2 print("Uchburchak yuzi:", xisoblash.uchburchak_yuza(10, 5))
#       3 print("To'rtburchak yuzi:", xisoblash.tortburchak_yuza(10, 5))
#
# ModuleNotFoundError: No module named 'xisoblash'

# %%
sonlar= [random.randint(1, 100) for _ in range(10)]
ortacha = sum(sonlar) / len(sonlar)
print(math.floor(ortacha))
# Out:
# 41

# %%
hafta_kuni = datetime.date.today().weekday()
if hafta_kuni == 5:
    print("Bugun shanba, dam oling!")
elif hafta_kuni == 6:
    print("Bugun yakshanba, dam oling!")
else:
    kunlar = ["dushanba", "seshanba", "chorshanba", "payshanba", "juma"]
    print(f"Bugun {kunlar[hafta_kuni]}, dam olish vaqti emas!")
# Out:
# Bugun shanba, dam oling!

# %%
kompyuter_soni = random.randint(1, 100)
for urinish in range(1, 6):
    taxmin = int(input("Sonni toping: "))
    if taxmin == kompyuter_soni:
        print(f"Tabriklaymiz! {urinish} ta urinishda topdingiz!")
        break
    elif taxmin > kompyuter_soni:
        print("Kichikroq!")
    else:
        print("Kattaroq!")
else:
    print(f"Imkoniyat tugadi. Son {kompyuter_soni} edi.")
# Out:
# Kattaroq!
# Kattaroq!
# Tabriklaymiz! 3 ta urinishda topdingiz!

# %%
# XATOLAR BILAN ISHLASH (TRY-EXCEPT)

# %%
while True:
    try:
        son12 = int(input("Son kiriting: "))
        break
    except ValueError:
        print("Iltimos, son kiriting!")

# %%
try:
    s1 = float(input("1-son: "))
    s2 = float(input("2-son: "))
    print(s1 / s2)
except ZeroDivisionError:
    print("Nolga bo'lib bo'lmaydi!")
except ValueError:
    print("Son kiriting!")
# Out:
# 1.0

# %%
ro_yxat = [10, 20, 30, 40, 50]
try:
    indeks = int(input("Indeks kiriting: "))
    print(ro_yxat[indeks])
except IndexError:
    print("Bunday indeks yo'q!")
except ValueError:
    print("To'g'ri indeks kiriting!")
# Out:
# Bunday indeks yo'q!

# %%
lugat = {"ism": "Ali", "yosh": 18, "shahar": "Toshkent"}
kalit = input("Kalit kiriting: ")
try:
    print(lugat[kalit])
except KeyError:
    print("Kalit mavjud emas")
# Out:
# Kalit mavjud emas

# %%
try:
    parol = input("Parol kiriting: ")
    if len(parol) < 6:
        raise ValueError("Parol 6 belgidan qisqa bo'lsa...")
except ValueError as e:
    print(e)
# Out:
# Parol 6 belgidan qisqa bo'lsa...

# %%
sonlar = []
while len(sonlar) < 3:
    try:
        s = float(input(f"{len(sonlar)+1}-sonni kiriting: "))
        sonlar.append(s)
    except ValueError:
        print("Xato, son kiriting!")

# %%
try:
    son = float(input("Son kiriting: "))
    if son < 0:
        raise ValueError("Manfiy son kiritildi!")
    print(math.sqrt(son))
except ValueError or SyntaxError as warn:
    print(e)
# Out:
# could not convert string to float: 'sjd'

# %%
try:
    yosh = int(input("Yosh kiriting: "))
    if yosh < 0 or yosh > 120:
        raise ValueError("Yosh noto'g'ri kiritildi!")
except ValueError as xato:
    print(e)
finally:
    print("Tekshiruv tugadi")

# %%
kompyuter_soni = random.randint(1, 100)
urinishlar = 0
while urinishlar < 5:
    try:
        taxmin = int(input("Sonni toping: "))
        urinishlar += 1
        if taxmin == kompyuter_soni :
            print(f"Tabriklaymiz! {urinishlar} ta urinishda topdingiz!")
            break
        elif taxmin > kompyuter_soni:
            print("Kichikroq!")
        else:
            print("Kattaroq!")
    except ValueError:
        print("Iltimos, son kiriting!")
else:
    print(f"Imkoniyat tugadi. Son {kompyuter_soni} edi.")
# Out:
# Kichikroq!
# Kichikroq!
# Kichikroq!
# Kattaroq!
# Kattaroq!
# Imkoniyat tugadi. Son 9 edi.
