# %%
isimlar=["ali","vali"]
natija={}
for ism in isimlar:
    # natija[ism]=natija.get(ism,0)+1
    if ism in natija.keys():
        natija[ism]+=1
    else:
        natija[ism]=1
print(natija)
# Out:
# {'ali': 1, 'vali': 1}
