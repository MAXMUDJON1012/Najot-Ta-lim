# %%
sonlar = []
for i in range(5):
    son = int(input(f"{i+1}-sonni kiriting: "))
    sonlar.append(son)

print("Hosil bo'lgan list:", sonlar)
# Out:
# Hosil bo'lgan list: [1, 2, 3, 5, 6]

# %%
my_list = [10, 20, 30, 40, 50]
yigindi = 0

for son in my_list:
    yigindi += son

print("Yig'indi:", yigindi)  # 1-usul  
print(sum(my_list))          # 2-usul
# Out:
# Yig'indi: 150
# 150

# %%
my_list = [12, 45, 2, 89, 34]
eng_katta = my_list[0]

for son in my_list:
    if son > eng_katta:
        eng_katta = son

print("Eng katta element:", eng_katta)  # 1-usul
print(max(my_list)) # 1-usul
# Out:
# Eng katta element: 89
# 89

# %%
my_list = [12, 45, 2, 89, 34]
eng_kichik = my_list[0]

for son in my_list:
    if son < eng_kichik:
        eng_kichik = son

print("Eng kichik element:", eng_kichik)
print(min(my_list))
# Out:
# Eng kichik element: 2
# 2

# %%
my_list = [4, 7, 12, 19, 24, 33, 40]
juft_count = 0

for son in my_list:
    if son % 2 == 0:
        juft_count += 1

print("Juft sonlar soni:", juft_count)
# Out:
# Juft sonlar soni: 4
# 7

# %%
my_list = [1, 2, 3, 4, 5]
uzunlik = len(my_list)
for i in range(uzunlik-1 , -1, -1):
    print(my_list[i])
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
my_list = [15, -3, 0, -8, 22, -1]

for son in my_list:
    if son < 0:
        print("Manfiy son:", son)
# Out:
# Manfiy son: -3
# Manfiy son: -8
# Manfiy son: -1

# %%
my_list = [10, 20, 30]
yangi_element = int(input("Yangi element kiriting: "))

my_list.append(yangi_element)
print("Yangilangan list:", my_list)
# Out:
# Yangilangan list: [10, 20, 30, 5]

# %%
my_list = [5, 10, 15, 20, 15, 30]
o_chirgich = int(input("O'chirmoqchi bo'lgan sonni kiriting: "))
yangi_list = []
for son in my_list:
    if son != o_chirgich:
        yangi_list.append(son)

my_list = yangi_list
print("Yangilangan list:", my_list)
# Out:
# Yangilangan list: [10, 15, 20, 15, 30]

# %%
my_list = [11, 22, 33, 44, 55]
qidirilayotgan_son = int(input("Son kiriting: "))
topildi = False
for son in my_list:
    if son == qidirilayotgan_son:
        topildi = True
        break
if topildi:
    print("Mavjud")
else:
    print("Mavjud emas")
# Out:
# Mavjud emas

# %%
# Tuple bo‘yicha masalalar



my_tuple = (14, 25, 36, 47, 58)
print("Hosil bo'lgan tuple:", my_tuple)
# Out:
# Hosil bo'lgan tuple: (14, 25, 36, 47, 58)

# %%
my_tuple = (1, 5, 9, 3, 7, 2, 8)
elementlar_soni = 0

for element in my_tuple:
    elementlar_soni += 1

print("Elementlar soni:", elementlar_soni)
# Out:
# Elementlar soni: 7

# %%
my_tuple = (14, 52, 8, 91, 63)
eng_katta = my_tuple[0]
for son in my_tuple:
    if son > eng_katta:
        eng_katta = son
print("Tuple ichidagi eng katta son:", eng_katta)
print(max(my_tuple))
# Out:
# Tuple ichidagi eng katta son: 91
# 91

# %%
my_tuple = (14, 52, 8, 91, 63)
eng_kichik = my_tuple[0]

for son in my_tuple:
    if son < eng_kichik:
        eng_kichik = son

print("Tuple ichidagi eng kichik son:", eng_kichik)
print(min(my_tuple))
# Out:
# Tuple ichidagi eng kichik son: 8
# 8

# %%
my_tuple = (5, 15, 25, 35)
yigindi = 0

for son in my_tuple:
    yigindi += son

print("Tuple elementlari yig'indisi:", yigindi)
print(sum(my_tuple))
# Out:
# Tuple elementlari yig'indisi: 80
# 80

# %%
my_tuple = (2, 5, 8, 11, 14, 17, 20)
toq_count = 0
for son in my_tuple:
    if son % 2 != 0:
        toq_count += 1
print("Toq sonlar soni:", toq_count)
# Out:
# Toq sonlar soni: 3

# %%
my_tuple = (100, 200, 300, 400, 500)
uzunlik = 0
for element in my_tuple:
    uzunlik += 1
birinchi = my_tuple[0]
oxirgi = my_tuple[uzunlik - 1]
print("Birinchi element:", birinchi)
print("Oxirgi element:", oxirgi)
# Out:
# Birinchi element: 100
# Oxirgi element: 500

# %%
my_tuple = ("olma", "anor", "behi", "anjir")

uzunlik = 0
for element in my_tuple:
    uzunlik += 1

for i in range(uzunlik - 1, -1, -1):
    print(my_tuple[i])
# Out:
# anjir
# behi
# anor
# olma

# %%
my_tuple = (10, 20, 30, 40, 50)
son = int(input("Tekshirish uchun son kiriting: "))
bor = False
for element in my_tuple:
    if element == son:
        bor = True
        break
if bor:
    print("Kiritilgan son tuple ichida bor.")
else:
    print("Kiritilgan son tuple ichida yo'q.")
# Out:
# Kiritilgan son tuple ichida yo'q.

# %%
tuple1 = (1, 2, 3)
tuple2 = (4, 5, 6)
yangi_tuple = tuple1 + tuple2

print("Birlashtirilgan tuple:", yangi_tuple)
# Out:
# Birlashtirilgan tuple: (1, 2, 3, 4, 5, 6)
