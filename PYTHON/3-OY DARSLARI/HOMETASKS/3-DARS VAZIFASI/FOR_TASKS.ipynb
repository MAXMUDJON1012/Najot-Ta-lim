# %%
k = int(input("k sonini kiriting: "))
n = int(input("n sonini kiriting: "))
for i in range(n):
    print(k)

# %%
a = int(input("a sonini kiriting: "))
b = int(input("b sonini kiriting"))
hisoblagich = 0
for i in range(a, b + 1):
    print(i)
    hisoblagich += 1
print(f"Chiqarilgan sonlar soni: {hisoblagich}")
# Out:
# 1
# 2
# 3
# 4
# 5
# Chiqarilgan sonlar soni: 5

# %%
a = int(input("a sonini kiriting: "))
b = int(input("b sonini kiriting"))
hisoblagich = 0
for i in range(b - 1, a, -1):
    print(i)
    hisoblagich += 1
print(f"Chiqarilgan sonlar soni: {hisoblagich}")

# %%
narx = float(input("1 kg konfetning narxini kiriting: "))
for kg in range(1, 11):
    jami_narx = kg * narx
    print(f"{kg} kg konfet = {jami_narx} so'm")

# %%
narx = float(input("1 kg konfetning narxini kiriting: "))

for i in range(1, 11):
    kg = i / 10
    jami_narx = kg * narx
    print(f"{kg:.1f} kg konfet = {jami_narx:.2f} so'm")

# %%
narx = float(input("1 kg konfetning narxini kiriting: "))
for i in range(12, 21, 2):
    kg = i / 10 
    jami_narx = kg * narx
    print(f"{kg:.1f} kg konfet = {jami_narx:.2f} so'm")

# %%
a = int(input("a sonini kiriting: "))
b = int(input("b sonini kiriting (a < b): "))
yigindi = 0
for i in range(a, b + 1):
    yigindi += i
print(f"{a} dan {b} gacha bo'lgan sonlar yig'indisi: {yigindi}")

# %%
a = int(input("a sonini kiriting: "))
b = int(input("b sonini kiriting (a < b): "))

kopaytma = 1

for i in range(a, b + 1):
    kopaytma *= i

print(f"{a} dan {b} gacha bo'lgan sonlar ko'paytmasi: {kopaytma}")

# %%
a = int(input("a sonini kiriting: "))
b = int(input("b sonini kiriting (a < b): "))

kvadratlar_yigindisi = 0

for i in range(a, b + 1):
    kvadratlar_yigindisi += i ** 2 

print(f"{a} dan {b} gacha bo'lgan sonlar kvadratlarining yig'indisi: {kvadratlar_yigindisi}")
