# %%
import mysql.connetor

mydb= mysql.connetor.connect(
    host = "localhost",
    user = "root",
    password = "2005",
    database = "school"
)
cursor = mydb.cursor()
# sql="INSERT INTO students (fullname, age, phone, score) VLUES (%s,%s,%s,%s)"
# val =("Eshmatov Toshmat", 20, "+998909900990", 10)
# cursor.execute(sql, val)
# mydb.commit()
# print("qo'shildi")
fulname=input("Enter fulname")
Age=int(input("Enter age"))
phone=input("Enter your phone number!")

cursor.execute("SELECT id, fullname, age from students; ")
data = cursor.fetchall()

from pprint import pprint
pprint(data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import mysql.connetor
#       2
#       3 mydb= mysql.connetor.connect(
#       4     host = "localhost",
#
# ModuleNotFoundError: No module named 'mysql.connetor'
